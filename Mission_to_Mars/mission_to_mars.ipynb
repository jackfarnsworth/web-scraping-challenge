# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import pymongo
from splinter import Browser
import time
from webdriver_manager.chrome import ChromeDriverManager

# %%
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)

# %%
# db = client.commerce_db
# collection = db.items

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\jackc\.wdm\drivers\chromedriver\win32\99.0.4844.51]

# %%
browser.visit('https://redplanetscience.com/')
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
#        <img src="image/nasa.png" width="80"/>
#        <span class="logo">
#         MARS Planet Science
#        </span>
#        <span class="logo1">
#         Exploration Program
#        </span>
#       </a>
#       <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
#        <span class="navbar-toggler-icon">
#        </span>
#       </button>
#       <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a aria-current="page" class="nav-link active" href="#">
#           The Red Planet
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           The Program
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           News &amp; Events
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           Multimedia
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           Missions
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           More
#          </a>
#         </li>
#         <li class="nav-item nav_search">
#          <a class="nav-link" href="#">
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <section class="search">
#      <div class="container">
#       <h1>
#        News
#       </h1>
#       <div class="col-md-12 filter">
#        <div class="row">
#         <div class="col-md-3 search_binder">
#          <input class="search_field" name="search" type="text"/>
#          <input class="search_submit" name="search" type="text"/>
#         </div>
#         <div class="col-md-3">
#          <select aria-label="Default select example" class="form-select" id="year">
#           <option selected="">
#            Latest
#           </option>
#           <option>
#            2019
#           </option>
#           <option>
#            2020
#           </option>
#          </select>
#         </div>
#         <div class="col-md-3">
#          <select aria-label="Default select example" class="form-select" id="cat">
#           <option selected="">
#            All Categories
#           </option>
#           <option>
#            Feature Stories
#           </option>
#           <option>
#            Press Releases
#           </option>
#           <option>
#            Status Reports
#           </option>
#          </select>
#         </div>
#         <div class="col-md-3">
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="image_and_description_container">
#      <div class="container" id="news">
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8504_insight20190822-226.gif"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 13, 2022
#           </div>
#           <div class="content_title">
#            NASA-JPL Names 'Rolling Stones Rock' on Mars
#           </div>
#           <div class="article_teaser_body">
#            NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8508_Name_A_unannotated_MAIN-th.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 12, 2022
#           </div>
#           <div class="content_title">
#            NASA Invites Students to Name Mars 2020 Rover
#           </div>
#           <div class="article_teaser_body">
#            Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8444_Sol427-437_backcap_push_positioning-320x240.gif"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 11, 2022
#           </div>
#           <div class="content_title">
#            Common Questions about InSight's 'Mole'
#           </div>
#           <div class="article_teaser_body">
#            The following Q&amp;As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8641_PIA-23821-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 9, 2022
#           </div>
#           <div class="content_title">
#            NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#           </div>
#           <div class="article_teaser_body">
#            After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8678_21379_PIA22107-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 8, 2022
#           </div>
#           <div class="content_title">
#            The Detective Aboard NASA's Perseverance Rover
#           </div>
#           <div class="article_teaser_body">
#            An instrument called SHERLOC will, with the help of its partner WATSON, hunt for signs of ancient life by detecting organic molecules and minerals.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8796_PIA24173-320.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 7, 2022
#           </div>
#           <div class="content_title">
#            NASA's Curiosity Takes Selfie With 'Mary Anning' on the Red Planet
#           </div>
#           <div class="article_teaser_body">
#            The Mars rover has drilled three samples of rock in this clay-enriched region since arriving in July.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8689_PIA23897-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 5, 2022
#           </div>
#           <div class="content_title">
#            NASA's Mars Rover Drivers Need Your Help
#           </div>
#           <div class="article_teaser_body">
#            Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8520_PIA23466-226.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            March 2, 2022
#           </div>
#           <div class="content_title">
#            NASA's Mars 2020 Rover Tests Descent-Stage Separation
#           </div>
#           <div class="article_teaser_body">
#            A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8695_24732_PIA23499-226.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            February 23, 2022
#           </div>
#           <div class="content_title">
#            The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#           </div>
#           <div class="article_teaser_body">
#            The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8568_PIA23515_annotated-globe-320x240.gif"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            February 21, 2022
#           </div>
#           <div class="content_title">
#            NASA's Treasure Map for Water Ice on Mars
#           </div>
#           <div class="article_teaser_body">
#            A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8621_sol2597_2600_mosaic-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            February 20, 2022
#           </div>
#           <div class="content_title">
#            NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet
#           </div>
#           <div class="article_teaser_body">
#            To go along with the stunning 1.8-billion-pixel image, a new video offers a sweeping view of the Red Planet.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8792_parachute-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            February 19, 2022
#           </div>
#           <div class="content_title">
#            NASA's Perseverance Rover 100 Days Out
#           </div>
#           <div class="article_teaser_body">
#            Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8782_PIA-23989-320.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            February 19, 2022
#           </div>
#           <div class="content_title">
#            Sensors on Mars 2020 Spacecraft Answer Long-Distance Call From Earth
#           </div>
#           <div class="article_teaser_body">
#            Instruments tailored to collect data during the descent of NASA's next rover through the Red Planet's atmosphere have been checked in flight.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8612_Sol427-437_backcap_push_positioning-320x240.gif"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            February 16, 2022
#           </div>
#           <div class="content_title">
#            Mars InSight Lander to Push on Top of the 'Mole'
#           </div>
#           <div class="article_teaser_body">
#            Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="https://mars.nasa.gov/system/news_items/list_view_images/8528_PIA23376-320x240.jpg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            February 13, 2022
#           </div>
#           <div class="content_title">
#            HiRISE Views NASA's InSight and Curiosity on Mars
#           </div>
#           <div class="article_teaser_body">
#            New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <hr class="container" style="margin: 25px auto;width: 83%;"/>
#      <button class="btn disable" id="more" onclick="populateContent()">
#       More
#      </button>
#     </section>
#     <section class="last_news">
#      <div class="container">
#       <div class="row">
#        <div class="col-12">
#         <h2>
#          You Might Also Like
#         </h2>
#        </div>
#        <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
#        <div class="col-12">
#         <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
#          <div class="carousel-inner">
#           <div class="carousel-item active">
#            <div class="row">
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="carousel-item">
#            <div class="row">
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="carousel-item">
#            <div class="row">
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
#               <div class="card-body">
#                <p class="card-text">
#                 With supporting text below as a natural lead-in to additional content.
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="footer">
#      <div class="container">
#       <div class="col-md-12">
#        <div class="row">
#         <div class="col-md-3">
#          <h5>
#           The Red Planet
#          </h5>
#          <ul>
#           <li>
#            Dashboard
#           </li>
#           <li>
#            Science Goals
#           </li>
#           <li>
#            The Planet
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           The Program
#          </h5>
#          <ul>
#           <li>
#            Mission Statement
#           </li>
#           <li>
#            About the Program
#           </li>
#           <li>
#            Organization Why Mars?
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           Multimedia
#          </h5>
#          <ul>
#           <li>
#            Images
#           </li>
#           <li>
#            Videos
#           </li>
#           <li>
#            More Resources
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           Missions
#          </h5>
#          <ul>
#           <li>
#            Past
#           </li>
#           <li>
#            Present
#           </li>
#           <li>
#            Future
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript">
#     </script>
#     <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js">
#     </script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js">
#     </script>
#     <script src="js/app.js">
#     </script>
#    </div>
#   </div>
#  </body>
# </html>

# %%
news_title = soup.find('div', class_="content_title").text
news_p = soup.find('div', class_="article_teaser_body").text

# %%
browser.visit('https://spaceimages-mars.com/')
browser.links.find_by_partial_text('FULL IMAGE').click()

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

print(soup.prettify())
# Out:
# <html class="fancybox-margin fancybox-lock">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" rel="stylesheet"/>
#   <!-- <link rel="stylesheet" type="text/css" href="css/font.css"> -->
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Space Image
#   </title>
#   <style type="text/css">
#    .fancybox-margin{margin-right:17px;}
#   </style>
#  </head>
#  <body>
#   <div class="header">
#    <nav class="navbar navbar-expand-lg">
#     <a class="navbar-brand" href="#">
#      <img id="logo" src="image/nasa.png"/>
#      <span class="logo">
#       Jet Propulsion Laboratory
#      </span>
#      <span class="logo1">
#       California Institute of Technology
#      </span>
#     </a>
#     <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon">
#      </span>
#     </button>
#     <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#      <ul class="navbar-nav">
#       <li class="nav-item active">
#        <a class="nav-link" href="#">
#         <i aria-hidden="true" class="fa fa-bars">
#         </i>
#         MENU
#         <i aria-hidden="true" class="fa fa-search">
#         </i>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <div class="floating_text_area">
#     <h2 class="brand_title">
#      FEATURED IMAGE
#     </h2>
#     <h1 class="media_feature_title">
#      Dusty Space Cloud
#     </h1>
#     <br/>
#     <a class="showimg fancybox-thumbs" href="image/featured/mars3.jpg" target="_blank">
#      <button class="btn btn-outline-light">
#       FULL IMAGE
#      </button>
#     </a>
#    </div>
#    <img class="headerimage fade-in" src="image/featured/mars3.jpg"/>
#   </div>
#   <div class="search sticky">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-6">
#       <input name="Search" placeholder="Search" type="text"/>
#      </div>
#      <div class="col-md-6">
#       <select aria-label="Default select example" class="form-select" id="options">
#        <option onchange="0" selected="">
#         Mars
#        </option>
#        <!-- <option data-filter="sun" class="button">Mars</option> -->
#        <option class="button" data-filter="Sun">
#         Sun
#        </option>
#        <option class="button" data-filter="earth">
#         Earth
#        </option>
#        <option class="button" data-filter="ida">
#         Ida
#        </option>
#        <option class="button" data-filter="jupiter">
#         Jupiter
#        </option>
#        <option class="button" data-filter="venus">
#         Venus
#        </option>
#       </select>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container mt-5">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-6">
#       <h1>
#        Images
#       </h1>
#      </div>
#      <div class="col-md-6" id="icon">
#       <div class="icon2">
#       </div>
#       <div class="icon1">
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- first div -->
#    <div class="div1" id="filter">
#     <div class="thmbgroup">
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Icaria Fossae7
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/>
#        <p class="thumbcontent">
#         December 31, 2020
#         <br/>
#         Proctor Crater Dunes
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/>
#        <p class="thumbcontent">
#         December 31, 2020
#         <br/>
#         Icaria Fossae
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/>
#        <p class="thumbcontent">
#         December 29, 2020
#         <br/>
#         Proctor Crater Dunes
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/>
#        <p class="thumbcontent">
#         December 28, 2020
#         <br/>
#         roctor Crater Dunes
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/>
#        <p class="thumbcontent">
#         December 22, 2020
#         <br/>
#         Icaria Fossae
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/>
#        <p class="thumbcontent">
#         December 21, 2020
#         <br/>
#         Icaria Fossae
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/>
#        <p class="thumbcontent">
#         December 18, 2020
#         <br/>
#         Ariadnes Colles
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>
#        <p class="thumbcontent">
#         December 17, 2020
#         <br/>
#         Niger Vallis
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/>
#        <p class="thumbcontent">
#         December 16, 2020
#         <br/>
#         Proctor Crater Dunes
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>
#        <p class="thumbcontent">
#         December 15, 2020
#         <br/>
#         Niger Vallis
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>
#        <p class="thumbcontent">
#         December 11, 2020
#         <br/>
#         Daedalia Planum
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Sirenum Fossae.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/>
#        <p class="thumbcontent">
#         November,11, 2020
#         <br/>
#         Sirenum Fossae
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/>
#        <p class="thumbcontent">
#         November,13, 2020
#         <br/>
#         Ariadnes Colles
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/>
#        <p class="thumbcontent">
#         November,14, 2020
#         <br/>
#         South Polar Cap
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>
#        <p class="thumbcontent">
#         November,17, 2020
#         <br/>
#         Daedalia Planum
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles3.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/>
#        <p class="thumbcontent">
#         November,11, 2020
#         <br/>
#         Ariadnes Colles
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Atlantis Chaos.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Atlantis Chaos.jpg"/>
#        <p class="thumbcontent">
#         November,09, 2020
#         <br/>
#         Atlantis Chaos
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Daedalia Planum
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Icaria Fossae
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Niger Vallis
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Proctor Crater Dunes
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Reull Vallis.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Reull Vallis.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Reull Vallis
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles3.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Ariadnes Colles
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Sirenum Fossae.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Sirenum Fossae
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         South Polar Cap
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Niger Vallis
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Daedalia Planum
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Icaria Fossae
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Ariadnes Colles
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         South Polar Cap
#        </p>
#       </div>
#      </a>
#      <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg">
#       <div class="thmb">
#        <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>
#        <p class="thumbcontent">
#         January 1, 2020
#         <br/>
#         Daedalia Planum
#        </p>
#       </div>
#      </a>
#     </div>
#    </div>
#    <!-- first div ends -->
#    <!-- second div starts -->
#    <div class="col-md-12 grid-margin" id="column">
#     <ul class="post-list">
#      <li class="post-heading">
#      </li>
#     </ul>
#    </div>
#    <!-- second div starts -->
#   </div>
#   <div class="first imgcontainer mt-3">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-3">
#       <img id="pic" src=""/>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- end -->
#   <div class="module_gallery container">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-6">
#       <div class="card">
#        <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#        <div class="card-body">
#         <h5 class="card-title">
#          JPL Photojournal
#         </h5>
#         <p class="card-text">
#          Access to the full library of publicly released images from various Solar System exploration programs
#         </p>
#        </div>
#       </div>
#      </div>
#      <div class="col-md-6">
#       <div class="card">
#        <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#        <div class="card-body">
#         <h5 class="card-title">
#          Great images in NASA
#         </h5>
#         <p class="card-text">
#          A selection of the best-known images from a half-century of exploration and discovery
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="multi_teaser">
#    <div class="container">
#     <h1>
#      You Might Also Like
#     </h1>
#     <div class="col-md-12 mt-5">
#      <div class="row">
#       <div class="col-md-4">
#        <div class="card">
#         <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#         <div class="card-body">
#          <p class="card-text">
#           Access to the full library of publicly released images from various Solar System exploration programs
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-4">
#        <div class="card">
#         <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#         <div class="card-body">
#          <p class="card-text">
#           Access to the full library of publicly released images from various Solar System exploration programs
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-4">
#        <div class="card">
#         <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#         <div class="card-body">
#          <p class="card-text">
#           Access to the full library of publicly released images from various Solar System exploration programs
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="footer">
#    <div class="container">
#     <div class="col-md-12">
#      <div class="row">
#       <div class="col-md-3">
#        <h4>
#         About JPL
#        </h4>
#        <ul>
#         <li>
#          About JPL
#         </li>
#         <li>
#          JPL Vision
#         </li>
#         <li>
#          Executive Council
#         </li>
#         <li>
#          History
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3">
#        <h4>
#         Education
#        </h4>
#        <ul>
#         <li>
#          Intern
#         </li>
#         <li>
#          Learn
#         </li>
#         <li>
#          Teach
#         </li>
#         <li>
#          News
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3">
#        <h4>
#         Our Sites
#        </h4>
#        <ul>
#         <li>
#          Asteroid Watch
#         </li>
#         <li>
#          Basics of Spaceflight
#         </li>
#         <li>
#          Cassini - Mission to Saturn
#         </li>
#         <li>
#          Climate Kids
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3">
#        <h4>
#         Galleries
#        </h4>
#        <ul>
#         <li>
#          JPL Space Images
#         </li>
#         <li>
#          Videos
#         </li>
#         <li>
#          Infographics
#         </li>
#         <li>
#          Photojournal
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--<div class="showFullimage">
# 	<button class="btn btn-outline-light hideimage" onclick=hideimage()> Close</button>
# 	<img class="fullimage fade-in" src="">
# </div>-->
#   <!-- <script src="js/jquery.easeScroll.js"></script>  -->
#   <script src="js/jquery-3.5.1.min.js">
#   </script>
#   <!-- <script src="js/jquery-3.2.1.slim.min.js"></script> -->
#   <script src="js/demo.js">
#   </script>
#   <!-- <script src="js/app.js"></script> -->
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js">
#   </script>
#   <script src="js/fancyBox/jquery.fancybox.pack.js?v=2.1.5" type="text/javascript">
#   </script>
#   <link href="js/fancyBox/jquery.fancybox.css?v=2.1.5" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="js/fancyBox/helpers/jquery.fancybox-thumbs.css?v=1.0.7" rel="stylesheet" type="text/css"/>
#   <script src="js/fancyBox/helpers/jquery.fancybox-thumbs.js?v=1.0.7" type="text/javascript">
#   </script>
#   <div class="fancybox-overlay fancybox-overlay-fixed" style="width: auto; height: auto; display: block;">
#    <div class="fancybox-wrap fancybox-desktop fancybox-type-image fancybox-opened" style="width: 646px; height: auto; position: absolute; top: 232px; left: 20px; opacity: 1; overflow: visible;" tabindex="-1">
#     <div class="fancybox-skin" style="padding: 15px; width: auto; height: auto;">
#      <div class="fancybox-outer">
#       <div class="fancybox-inner" style="overflow: visible; width: 616px; height: 336px;">
#        <img alt="" class="fancybox-image" src="image/featured/mars3.jpg"/>
#       </div>
#      </div>
#      <a class="fancybox-item fancybox-close" href="javascript:;" title="Close">
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
featured_image_url = f'https://spaceimages-mars.com/{soup.find("img", class_="headerimage")["src"]}'
# Out:
# https://spaceimages-mars.com/image/featured/mars3.jpg

# %%
browser.visit('https://galaxyfacts-mars.com/')

# %%
tables = pd.read_html('https://galaxyfacts-mars.com/')
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_Seinfeld_episodes#Season_1_1989-90')

# %%
mars_df = tables[1]
mars_df
# Out:
# 0  Equatorial Diameter:                       6,792 km
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
mars_df.columns = mars_df.iloc[0] 
mars_df = mars_df[1:]
mars_df
# Out:
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
mars_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Equatorial Diameter:</th>\n      <th>6,792 km</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Equatorial Diameter:</td>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Polar Diameter:</td>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mass:</td>\n      <td>6.39 × 10^23 kg (0.11 Earths)</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Moons:</td>\n      <td>2 ( Phobos &amp; Deimos )</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Orbit Distance:</td>\n      <td>227,943,824 km (1.38 AU)</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Orbit Period:</td>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Surface Temperature:</td>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>First Record:</td>\n      <td>2nd millennium BC</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Recorded By:</td>\n      <td>Egyptian astronomers</td>\n    </tr>\n  </tbody>\n</table>'

# %%
url = 'https://marshemispheres.com/'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

links = soup.find_all('div', class_='item')

hemisphere_image_urls = []
for link in links:
    browser.visit(url + link.find("a")["href"])
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    hemisphere_image_urls.append({"title" : link.find('h3').text.replace(" Enhanced", ''), 
                                  "img_url": url + soup.find('div', class_='downloads').find('a')['href']})

# %%
hemisphere_image_urls
# Out:
# [{'title': 'Cerberus Hemisphere',
#   'img_url': 'https://marshemispheres.com/images/full.jpg'},
#  {'title': 'Schiaparelli Hemisphere',
#   'img_url': 'https://marshemispheres.com/images/schiaparelli_enhanced-full.jpg'},
#  {'title': 'Syrtis Major Hemisphere',
#   'img_url': 'https://marshemispheres.com/images/syrtis_major_enhanced-full.jpg'},
#  {'title': 'Valles Marineris Hemisphere',
#   'img_url': 'https://marshemispheres.com/images/valles_marineris_enhanced-full.jpg'}]

# %%
# Out:
# '<html lang="en">\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <link href="css/jquery-ui.css" rel="stylesheet" type="text/css"/>\n  <title>\n   Astropedia Search Results | GUSS Astrogeology Science Center\n  </title>\n  <meta content="GUSS Astrogeology Science Center Astropedia search results." name="description"/>\n  <meta content="GUSS,Astrogeology Science Center,Cartography,Geology,Space,Geological Survey,Mapping" name="keywords"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>\n  <link href="css/main.css" media="screen" rel="stylesheet"/>\n  <link href="css/print.css" media="print" rel="stylesheet"/>\n  <link href="#" rel="icon" type="image/x-ico"/>\n </head>\n <body id="results">\n  <header>\n   <a href="#" style="float:right;margin-top:10px;" target="_blank">\n    <img alt="USGS: Science for a Changing World" class="logo" height="60" src="images/usgs_logo_main_2x.png"/>\n   </a>\n   <a href="#" style="float:right;margin-top:5px;margin-right:20px;" target="_blank">\n    <img alt="NASA" class="logo" height="65" src="images/nasa-logo-web-med.png"/>\n   </a>\n  </header>\n  <div class="wrapper">\n   <div class="container">\n    <div class="widget block bar">\n     <a href="https://astrogeology.usgs.gov/search" style="float:right;text-decoration:none;">\n      <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>\n      <div style="clear:both;font-size:.8em;float:right;color:#888;">\n       Lunar and Planetary Cartographic\n                        Catalog\n      </div>\n     </a>\n     <div style="float:left;height:60px;">\n     </div>\n    </div>\n    <!--==============================================================-->\n    <div class="wide-image-wrapper" id="wide-image">\n     <div class="downloads">\n      <img class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/>\n      <h3>\n       Download\n      </h3>\n      <ul>\n       <li>\n        <a href="images/valles_marineris_enhanced-full.jpg" target="_blank">\n         Sample\n        </a>\n        (jpg) 1024px wide\n       </li>\n       <li>\n        <a href="images/valles_marineris_enhanced.tif" target="_blank">\n         Original\n        </a>\n        (tif\n        <span class="tooltip word-tif" title="">\n        </span>\n        ) 27 MB\n       </li>\n      </ul>\n     </div>\n     <img class="wide-image" src="images/b3c7c6c9138f57b4756be9b9c43e3a48_valles_marineris_enhanced.tif_full.jpg"/>\n     <a class="open-toggle" href="#open" id="wide-image-toggle">\n      Open\n     </a>\n    </div>\n    <div class="cover">\n     <h2 class="title">\n      Valles Marineris Hemisphere Enhanced\n     </h2>\n     <p>\n      Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to\n                that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of the\n                planet, with the scale being .6km/pixel. The mosaic is composed of 102 Viking Orbiter images of Mars.\n                The center of the scene (lat -8, long 78) shows the entire Valles Marineris canyon system, over 2000\n                kilometers long and up to 8 kilometers deep, extending form Noctis Labyrinthus, the arcuate system of\n                graben to the west, to the chaotic terrain to the east. Many huge ancient river channels begin from the\n                chaotic terrain from north-central canyons and run north. The three Tharsis volcanoes (dark red spots),\n                each about 25 kilometers high, are visible to the west. South of Valles Marineris is very ancient\n                terrain covered by many impact craters.\n     </p>\n     <!-- <div class="downloads">\n                     <img class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_t ...

# %%
# Out:
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="css/jquery-ui.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Astropedia Search Results | GUSS Astrogeology Science Center
#   </title>
#   <meta content="GUSS Astrogeology Science Center Astropedia search results." name="description"/>
#   <meta content="GUSS,Astrogeology Science Center,Cartography,Geology,Space,Geological Survey,Mapping" name="keywords"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link href="css/main.css" media="screen" rel="stylesheet"/>
#   <link href="css/print.css" media="print" rel="stylesheet"/>
#   <link href="#" rel="icon" type="image/x-ico"/>
#  </head>
#  <body id="results">
#   <header>
#    <a href="#" style="float:right;margin-top:10px;" target="_blank">
#     <img alt="USGS: Science for a Changing World" class="logo" height="60" src="images/usgs_logo_main_2x.png"/>
#    </a>
#    <a href="#" style="float:right;margin-top:5px;margin-right:20px;" target="_blank">
#     <img alt="NASA" class="logo" height="65" src="images/nasa-logo-web-med.png"/>
#    </a>
#   </header>
#   <div class="wrapper">
#    <div class="container">
#     <div class="widget block bar">
#      <a href="https://astrogeology.usgs.gov/search" style="float:right;text-decoration:none;">
#       <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>
#       <div style="clear:both;font-size:.8em;float:right;color:#888;">
#        Lunar and Planetary Cartographic
#                         Catalog
#       </div>
#      </a>
#      <div style="float:left;height:60px;">
#      </div>
#     </div>
#     <!--==============================================================-->
#     <div class="wide-image-wrapper" id="wide-image">
#      <div class="downloads">
#       <img class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/>
#       <h3>
#        Download
#       </h3>
#       <ul>
#        <li>
#         <a href="images/valles_marineris_enhanced-full.jpg" target="_blank">
#          Sample
#         </a>
#         (jpg) 1024px wide
#        </li>
#        <li>
#         <a href="images/valles_marineris_enhanced.tif" target="_blank">
#          Original
#         </a>
#         (tif
#         <span class="tooltip word-tif" title="">
#         </span>
#         ) 27 MB
#        </li>
#       </ul>
#      </div>
#      <img class="wide-image" src="images/b3c7c6c9138f57b4756be9b9c43e3a48_valles_marineris_enhanced.tif_full.jpg"/>
#      <a class="open-toggle" href="#open" id="wide-image-toggle">
#       Open
#      </a>
#     </div>
#     <div class="cover">
#      <h2 class="title">
#       Valles Marineris Hemisphere Enhanced
#      </h2>
#      <p>
#       Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to
#                 that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of the
#                 planet, with the scale being .6km/pixel. The mosaic is composed of 102 Viking Orbiter images of Mars.
#                 The center of the scene (lat -8, long 78) shows the entire Valles Marineris canyon system, over 2000
#                 kilometers long and up to 8 kilometers deep, extending form Noctis Labyrinthus, the arcuate system of
#                 graben to the west, to the chaotic terrain to the east. Many huge ancient river channels begin from the
#                 chaotic terrain from north-central canyons and run north. The three Tharsis volcanoes (dark red spots),
#                 each about 25 kilometers high, are visible to the west. South of Valles Marineris is very ancient
#                 terrain covered by many impact craters.
#      </p>
#      <!-- <div class="downloads">
#                      <img class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png">
#                      <h3>Download</h3>
#                      <ul>
#                         <li><a target="_blank" href="images/full.jpg">Sample</a> (jpg) 1024px wide</li>
#                         <li><a target="_blank" href="images/cerberus_enhanced.tif">Original</a> (tif<span class="tooltip word-tif" title=""></span>) 21 MB</li>
#                      </ul>
#                   </div> -->
#      <div class="description">
#       <dl>
#        <dt>
#         Mimetype
#        </dt>
#        <dd>
#         image/tiff
#        </dd>
#        <dt>
#         Filename
#        </dt>
#        <dd>
#         <a href="images/valles_marineris_enhanced.tif">
#          valles_marineris_enhanced.tif
#          <span class="tooltip word-tif" title="">
#          </span>
#         </a>
#        </dd>
#        <dt>
#         Originator
#        </dt>
#        <dd>
#        </dd>
#        <dt>
#         Group
#        </dt>
#        <dd>
#        </dd>
#        <dt>
#         Added to Astropedia
#        </dt>
#        <dd>
#         29 September 2011
#        </dd>
#        <dt>
#         Modified
#        </dt>
#        <dd>
#         3 November 2017
#        </dd>
#       </dl>
#      </div>
#     </div>
#     <!--==============================================================-->
#     <div class="navigation clear">
#      <a class="itemLink product-item" href="index.html">
#       <h3>
#        Back
#       </h3>
#      </a>
#     </div>
#    </div>
#    <footer>
#     <div class="left">
#      <a href="#">
#       Search
#      </a>
#      |
#      <a href="#">
#       About
#      </a>
#      |
#      <a href="#">
#       Contact
#      </a>
#     </div>
#     <div class="right">
#      <a href="#">
#       GUSS Science Center
#      </a>
#     </div>
#    </footer>
#   </div>
#   <div class="page-background" style="
#          background:url('./images/mars.jpg');
#          filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(
#          src='./images/mars.jpg', sizingMethod='scale');
#          ">
#   </div>
#   <script type="text/javascript">
#    var baseUrl = "";
#   </script>
#   <script src="js/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="js/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script src="js/general.js" type="text/javascript">
#   </script>
#   <script src="js/app.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
browser.windows[0].close()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-6-6b431a8829bb> in <module>
# ----> 1 browser.windows[0].close()
#
# ~\anaconda3\envs\pythondata\lib\site-packages\splinter\driver\webdriver\__init__.py in close(self)
#     153
#     154         with switch_window(self._browser, self.name):
# --> 155             self._browser.driver.close()
#     156
#     157         if target is not None:
#
# ~\anaconda3\envs\pythondata\lib\site-packages\splinter\driver\webdriver\__init__.py in __exit__(self, type, value, traceback)
#      67
#      68     def __exit__(self, type, value, traceback):
# ---> 69         if self.current_window_handle in self.browser.driver.window_handles:
#      70             self.browser.driver.switch_to.window(self.current_window_handle)
#      71
#
# ~\anaconda3\envs\pythondata\lib\site-packages\selenium\webdriver\remote\webdriver.py in window_handles(self)
#     722         """
#     723         if self.w3c:
# --> 724             return self.execute(Command.W3C_GET_WINDOW_HANDLES)['value']
#     725         else:
#     726             return self.execute(Command.GET_WINDOW_HANDLES)['value']
#
# ~\anaconda3\envs\pythondata\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\pythondata\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSessionIdException: Message: invalid session id

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_Seinfeld_episodes#Season_1_1989-90')
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_Seinfeld_episodes#Season_1_1989-90')

# %%
tables
# Out:
# [  Season          Episodes               Originally aired                 \
#    Season Season.1 Episodes Episodes.1         First aired     Last aired
#  0    NaN        1        5          5        July 5, 1989  June 21, 1990
#  1    NaN        2       12         12    January 23, 1991  June 26, 1991
#  2    NaN        3       23         23  September 18, 1991    May 6, 1992
#  3    NaN        4       24         24     August 12, 1992   May 20, 1993
#  4    NaN        5       22         22  September 16, 1993   May 19, 1994
#  5    NaN        6       24         24  September 22, 1994   May 11, 1995
#  6    NaN        7       24         24  September 21, 1995   May 16, 1996
#  7    NaN        8       22         22  September 19, 1996   May 15, 1997
#  8    NaN        9       24         24  September 25, 1997   May 14, 1998
#
#       Rank Rating Viewers (millions)
#       Rank Rating Viewers (millions)
#  0     NaN    NaN               19.2
#  1     NaN    NaN               18.1
#  2  41[10]   12.3               17.7
#  3  25[11]   13.7               20.0
#  4   3[12]   19.4               29.6
#  5   1[13]   20.6               31.1
#  6   2[14]   21.2               33.1
#  7   2[15]   20.5               32.3
#  8   1[16]   22.0               35.5  ,
#     No.overall  No. inseason                      Title   Directed by  \
#  0           1             1  "The Seinfeld Chronicles"     Art Wolff
#  1           2             2            "The Stake Out"  Tom Cherones
#  2           3             3              "The Robbery"  Tom Cherones
#  3           4             4           "Male Unbonding"  Tom Cherones
#  4           5             5            "The Stock Tip"  Tom Cherones
#
#                       Written by Original air date [17]  Prod.code [18]  \
#  0  Larry David & Jerry Seinfeld           July 5, 1989             101
#  1  Larry David & Jerry Seinfeld           May 31, 1990             103
#  2                  Matt Goldman           June 7, 1990             104
#  3  Larry David & Jerry Seinfeld          June 14, 1990             102
#  4  Larry David & Jerry Seinfeld          June 21, 1990             105
#
#    US viewers(millions)
#  0             15.4[19]
#  1             22.5[20]
#  2             19.7[21]
#  3             19.1[22]
#  4             19.4[23]  ,
#      No.overall  No. inseason                     Title   Directed by  \
#  0            6             1       "The Ex-Girlfriend"  Tom Cherones
#  1            7             2         "The Pony Remark"  Tom Cherones
#  2            8             3              "The Jacket"  Tom Cherones
#  3            9             4       "The Phone Message"  Tom Cherones
#  4           10             5           "The Apartment"  Tom Cherones
#  5           11             6              "The Statue"  Tom Cherones
#  6           12             7             "The Revenge"  Tom Cherones
#  7           13             8        "The Heart Attack"  Tom Cherones
#  8           14             9                "The Deal"  Tom Cherones
#  9           15            10         "The Baby Shower"  Tom Cherones
#  10          16            11  "The Chinese Restaurant"  Tom Cherones
#  11          17            12              "The Busboy"  Tom Cherones
#
#                        Written by Original air date [17]  Prod.code [18]  \
#  0   Larry David & Jerry Seinfeld       January 23, 1991             201
#  1   Larry David & Jerry Seinfeld       January 30, 1991             202
#  2   Larry David & Jerry Seinfeld       February 6, 1991             205
#  3   Larry David & Jerry Seinfeld      February 13, 1991             207
#  4                  Peter Mehlman          April 4, 1991             208
#  5                  Larry Charles         April 11, 1991             210
#  6                    Larry David         April 18, 1991             212
#  7                  Larry Charles         April 25, 1991             211
#  8                    Larry David            May 2, 1991             213
#  9                  Larry Charles           May 16, 1991             204
#  10  Larry David & Jerry Seinfeld           May 23, 1991             206
#  11  Larry David & Jerry Seinfeld          June 26, 1991             203
#
#     US viewers(millions)
#  0              15.6[24]
#  1              15.2[25]
#  2              14.8[26]
#  3              13.6[27]
#  4              24.7[28]
#  5              23.3[29]
#  6              19.6[30]
#  7              20.6[31]
#  8              22.9[32]
#  9              17.2[33]
#  10             16.8[34]
#  11             12.5[35]  ,
#      No.overall  No. inseason                            Title  \
#  0           18             1                       "The Note"
#  1           19             2                      "The Truth"
#  2           20             3                        "The Pen"
#  3           21             4                        "The Dog"
#  4           22             5                    "The Library"
#  5           23             6             "The Parking Garage"
#  6           24             7                       "The Café"
#  7           25             8                       "The Tape"
#  8           26             9                   "The Nose Job"
#  9           27            10                   "The Stranded"
#  10          28            11             "The Alternate Side"
#  11          29            12                    "The Red Dot"
#  12          30            13                     "The Subway"
#  13          31            14              "The Pez Dispenser"
#  14          32            15                    "The Suicide"
#  15          33            16                     "The Fix-Up"
#  16        3435          1718  "The Boyfriend""The New Friend"
#  17          36            19                       "The Limo"
#  18          37            20             "The Good Samaritan"
#  19          38            21                     "The Letter"
#  20          39            22              "The Parking Space"
#  21          40            23                       "The Keys"
#
#          Directed by                                        Written by  \
#  0      Tom Cherones                                       Larry David
#  1   David Steinberg                                       Elaine Pope
#  2      Tom Cherones                                       Larry David
#  3      Tom Cherones                                       Larry David
#  4      Joshua White                                     Larry Charles
#  5      Tom Cherones                                       Larry David
#  6      Tom Cherones                                       Tom Leopold
#  7   David Steinberg            Larry David and Bob Shaw & Don McEnery
#  8      Tom Cherones                                     Peter Mehlman
#  9      Tom Cherones     Larry David & Jerry Seinfeld and Matt Goldman
#  10     Tom Cherones                      Larry David and Bill Masters
#  11     Tom Cherones                                       Larry David
#  12     Tom Cherones                                     Larry Charles
#  13     Tom Cherones                                       Larry David
#  14     Tom Cherones                                       Tom Leopold
#  15     Tom Cherones                       Elaine Pope & Larry Charles
#  16     Tom Cherones                       Larry David and Larry Levin
#  17     Tom Cherones  Story by : Marc JaffeTeleplay by : Larry Charles
#  18  Jason Alexander                                     Peter Mehlman
#  19     Tom Cherones                                       Larry David
#  20     Tom Cherones                      Larry David and Greg Daniels
#  21     Tom Cherones                                     Larry Charles
#
#     Original air date [17] Prod.code [36] US viewers(millions)
#  0      September 18, 1991            301             21.7[37]
#  1      September 25, 1991            302             16.7[38]
#  2         October 2, 1991            305             15.1[39]
#  3         October 9, 1991            303             17.2[40]
#  4        October 16, 1991            304             16.4[41]
#  5        October 30, 1991            306             17.0[42]
#  6        November 6, 1991            307             16.4[43]
#  7       November 13, 1991            308             15.8[44]
#  8       November 20, 1991            309             16.3[45]
#  9       November 27, 1991        209[46]             18.6[47]
#  10       December 4, 1991            310             18.0[48]
#  11      December 11, 1991            311             17.9[49]
#  12        January 8, 1992            313             18.7[50]
#  13       January 15, 1992            314             19.2[51]
#  14       January 29, 1992            312             16.9[52]
#  15       February 5, 1992            317             18.5[53]
#  16      February 12, 1992         315316             17.0[54]
#  17      February 26, 1992            318             19.5[55]
#  18          March 4, 1992            319             16.1[56]
#  19         March 25, 1992            320             22.3[57]
#  20         April 22, 1992            322             17.8[58]
#  21            May 6, 1992            321             16.4[59]  ,
#      No.overall  No. inseason                  Title   Directed by  \
#  0         4142            12             "The Trip"  Tom Cherones
#  1           43             3            "The Pitch"  Tom Cherones
#  2           44             4           "The Ticket"  Tom Cherones
#  3           45             5           "The Wallet"  Tom Cherones
#  4           46             6            "The Watch"  Tom Cherones
#  5           47             7       "The Bubble Boy"  Tom Cherones
#  6           48             8  "The Cheever Letters"  Tom Cherones
#  7           49             9            "The Opera"  Tom Cherones
#  8           50            10           "The Virgin"  Tom Cherones
#  9           51            11          "The Contest"  Tom Cherones
#  10          52            12          "The Airport"  Tom Cherones
#  11          53            13             "The Pick"  Tom Cherones
#  12          54            14            "The Movie"  Tom Cherones
#  13          55            15             "The Visa"  Tom Cherones
#  14          56            16            "The Shoes"  Tom Cherones
#  15          57            17           "The Outing"  Tom Cherones
#  16          58            18          "The Old Man"  Tom Cherones
#  17          59            19          "The Implant"  Tom Cherones
#  18          60            20      "The Junior Mint"  Tom Cherones
#  19          61            21       "The Smelly Car"  Tom Cherones
#  20          62            22    "The Handicap Spot"  Tom Cherones
#  21        6364          2324            "The Pilot"  Tom Cherones
#
#                                             Written by  \
#  0                                       Larry Charles
#  1                                         Larry David
#  2                                         Larry David
#  3                                         Larry David
#  4                                         Larry David
#  5                         Larry David & Larry Charles
#  6   Story by : Larry David and Elaine Pope & Tom L...
#  7                                       Larry Charles
#  8   Story by : Peter Mehlman and Peter Farrelly & ...
#  9                                         Larry David
#  10                                      Larry Charles
#  11  Story by : Larry David and Marc JaffeTeleplay ...
#  12          Steve Skrovan & Bill Masters & Jon Hayman
#  13                                      Peter Mehlman
#  14                       Larry David & Jerry Seinfeld
#  15                                      Larry Charles
#  16  Story by : Bruce KirschbaumTeleplay by : Larry...
#  17                                      Peter Mehlman
#  18                                         Andy Robin
#  19                        Larry David & Peter Mehlman
#  20                                        Larry David
#  21                                        Larry David
#
#              Original air date [17]  Prod.code [60] US viewers(millions)
#  0   August 12, 1992August 19, 1992          401402     16.3[61]15.1[62]
#  1               September 16, 1992             403             17.6[63]
#  2               September 16, 1992             404             17.6[63]
#  3               September 23, 1992             405             17.6[64]
#  4               September 30, 1992             406             15.2[65]
#  5                  October 7, 1992             407             17.1[66]
#  6                 October 28, 1992             408             15.1[67]
#  7                 November 4, 1992             409             16.7[68]
#  8                November 11, 1992             410             16.2[69]
#  9                November 18, 1992             411             18.5[70]
#  10               November 25, 1992             412             14.5[71]
#  11               December 16, 1992             413             16.2[72]
#  12                 January 6, 1993             415             17.6[73]
#  13                January 27, 1993             414             11.5[74]
#  14                February 4, 1993             417             26.9[74]
#  15               February 11, 1993             416             28.0[75]
#  16               February 18, 1993             418             22.7[76]
#  17               February 25, 1993             419             27.4[77]
#  18                  March 18, 1993             421             26.4[78]
#  19                  April 15, 1993             422             25.0[79]
#  20                    May 13, 1993             420             27.6[80]
#  21                    May 20, 1993          423424             32.8[81]  ,
#      No.overall  No. inseason                      Title   Directed by  \
#  0           65             1                "The Mango"  Tom Cherones
#  1           66             2          "The Puffy Shirt"  Tom Cherones
#  2           67             3              "The Glasses"  Tom Cherones
#  3           68             4  "The Sniffing Accountant"  Tom Cherones
#  4           69             5                 "The Bris"  Tom Cherones
#  5           70             6           "The Lip Reader"  Tom Cherones
#  6           71             7       "The Non-Fat Yogurt"  Tom Cherones
#  7           72             8               "The Barber"  Tom Cherones
#  8           73             9             "The Masseuse"  Tom Cherones
#  9           74            10   "The Cigar Store Indian"  Tom Cherones
#  10          75            11           "The Conversion"  Tom Cherones
#  11          76            12                "The Stall"  Tom Cherones
#  12          77            13         "The Dinner Party"  Tom Cherones
#  13          78            14     "The Marine Biologist"  Tom Cherones
#  14          79            15                  "The Pie"  Tom Cherones
#  15          80            16             "The Stand-In"  Tom Cherones
#  16          81            17                 "The Wife"  Tom Cherones
#  17        8283          1819            "The Raincoats"  Tom Cherones
#  18          84            20                 "The Fire"  Tom Cherones
#  19          85            21             "The Hamptons"  Tom Cherones
#  20          86            22             "The Opposite"  Tom Cherones
#
#                                             Written by Original air date [17]  \
#  0   Story by : Lawrence H. LevyTeleplay by : Lawre...     September 16, 1993
#  1                                         Larry David     September 23, 1993
#  2                             Tom Gammill & Max Pross     September 30, 1993
#  3                        Larry David & Jerry Seinfeld        October 7, 1993
#  4                                       Larry Charles       October 14, 1993
#  5                                        Carol Leifer       October 28, 1993
#  6                                         Larry David       November 4, 1993
#  7                                          Andy Robin      November 11, 1993
#  8                                       Peter Mehlman      November 18, 1993
#  9                             Tom Gammill & Max Pross       December 9, 1993
#  10                                   Bruce Kirschbaum      December 16, 1993
#  11                                      Larry Charles        January 6, 1994
#  12                                        Larry David       February 3, 1994
#  13                          Ron Hauge & Charlie Rubin      February 10, 1994
#  14                            Tom Gammill & Max Pross      February 17, 1994
#  15                                        Larry David      February 24, 1994
#  16                                      Peter Mehlman         March 17, 1994
#  17  Tom Gammill & Max Pross and Larry David & Jerr...         April 28, 1994
#  18                                      Larry Charles            May 5, 1994
#  19                       Peter Mehlman & Carol Leifer           May 12, 1994
#  20        Andy Cowan and Larry David & Jerry Seinfeld           May 19, 1994
#
#      Prod.code [82] US viewers(millions)
#  0              501             28.2[83]
#  1              503             29.5[84]
#  2              502             28.7[85]
#  3              504             28.4[86]
#  4              505             28.7[87]
#  5              506             31.0[88]
#  6              507             31.1[89]
#  7              508             29.7[90]
#  8              509             27.7[91]
#  9              510             29.6[92]
#  10             511             28.3[93]
#  11             512             35.0[94]
#  12             514             33.0[95]
#  13             513             35.0[96]
#  14             515                  NaN
#  15             516             25.4[97]
#  16             517             30.7[98]
#  17          519520             29.6[99]
#  18             518            27.6[100]
#  19             522            24.5[101]
#  20             521            30.1[102]  ,
#      No.overall  No. inseason                    Title         Directed by  \
#  0           87             1          "The Chaperone"       Andy Ackerman
#  1           88             2          "The Big Salad"       Andy Ackerman
#  2           89             3       "The Pledge Drive"       Andy Ackerman
#  3           90             4      "The Chinese Woman"       Andy Ackerman
#  4           91             5              "The Couch"       Andy Ackerman
#  5           92             6            "The Gymnast"       Andy Ackerman
#  6           93             7               "The Soup"       Andy Ackerman
#  7           94             8    "The Mom & Pop Store"       Andy Ackerman
#  8           95             9          "The Secretary"  David Owen Trainor
#  9           96            10               "The Race"       Andy Ackerman
#  10          97            11             "The Switch"       Andy Ackerman
#  11          98            12        "The Label Maker"       Andy Ackerman
#  12          99            13           "The Scofflaw"       Andy Ackerman
#  13      100101          1415  "The Highlights of 100"       Andy Ackerman
#  14         102            16              "The Beard"       Andy Ackerman
#  15         103            17         "The Kiss Hello"       Andy Ackerman
#  16         104            18            "The Doorman"       Andy Ackerman
#  17         105            19              "The Jimmy"       Andy Ackerman
#  18         106            20             "The Doodle"       Andy Ackerman
#  19         107            21      "The Fusilli Jerry"       Andy Ackerman
#  20         108            22    "The Diplomat's Club"       Andy Ackerman
#  21         109            23       "The Face Painter"       Andy Ackerman
#  22         110            24         "The Understudy"       Andy Ackerman
#
#                                             Written by Original air date [17]  \
#  0             Larry David and Bill Masters & Bob Shaw     September 22, 1994
#  1                                         Larry David     September 29, 1994
#  2                             Tom Gammill & Max Pross        October 6, 1994
#  3                                       Peter Mehlman       October 13, 1994
#  4                                         Larry David       October 27, 1994
#  5                           Alec Berg & Jeff Schaffer       November 3, 1994
#  6                                        Fred Stoller      November 10, 1994
#  7                             Tom Gammill & Max Pross      November 17, 1994
#  8                       Carol Leifer & Marjorie Gross       December 8, 1994
#  9   Story by : Tom Gammill & Max Pross and Larry D...      December 15, 1994
#  10                      Bruce Kirschbaum and Sam Kass        January 5, 1995
#  11                          Alec Berg & Jeff Schaffer       January 19, 1995
#  12                                      Peter Mehlman       January 26, 1995
#  13                                      Peter Mehlman       February 2, 1995
#  14                                       Carol Leifer       February 9, 1995
#  15                       Larry David & Jerry Seinfeld      February 16, 1995
#  16                            Tom Gammill & Max Pross      February 23, 1995
#  17                           Gregg Kavet & Andy Robin         March 16, 1995
#  18                          Alec Berg & Jeff Schaffer          April 6, 1995
#  19  Story by : Marjorie Gross & Jonathan Gross and...         April 27, 1995
#  20                            Tom Gammill & Max Pross            May 4, 1995
#  21  Story by : Larry David and Fred StollerTelepla...           May 11, 1995
#  22                      Marjorie Gross & Carol Leifer           May 18, 1995
#
#      Prod.code [103] US viewers(millions)
#  0               601            32.8[104]
#  1               602            32.4[105]
#  2               603            29.8[106]
#  3               604            29.2[107]
#  4               605            28.0[108]
#  5               606            30.6[109]
#  6               608            29.6[110]
#  7               607            32.4[111]
#  8               609            29.7[112]
#  9               612            26.8[113]
#  10              610            36.6[114]
#  11              611            36.2[115]
#  12              613            33.4[116]
#  13           623624            34.0[117]
#  14              615            32.9[118]
#  15              614            33.4[119]
#  16              616            33.4[120]
#  17              617            31.1[121]
#  18              618            30.7[122]
#  19              619            28.2[123]
#  20              620            28.9[124]
#  21              622            26.5[125]
#  22              621            29.8[126]  ,
#      No.overall  No. inseason                 Title    Directed by  \
#  0          111             1      "The Engagement"  Andy Ackerman
#  1          112             2    "The Postponement"  Andy Ackerman
#  2          113             3         "The Maestro"  Andy Ackerman
#  3          114             4            "The Wink"  Andy Ackerman
#  4          115             5         "The Hot Tub"  Andy Ackerman
#  5          116             6       "The Soup Nazi"  Andy Ackerman
#  6          117             7     "The Secret Code"  Andy Ackerman
#  7          118             8        "The Pool Guy"  Andy Ackerman
#  8          119             9          "The Sponge"  Andy Ackerman
#  9          120            10             "The Gum"  Andy Ackerman
#  10         121            11             "The Rye"  Andy Ackerman
#  11         122            12           "The Caddy"  Andy Ackerman
#  12         123            13           "The Seven"  Andy Ackerman
#  13      124125          1415        "The Cadillac"  Andy Ackerman
#  14         126            16     "The Shower Head"  Andy Ackerman
#  15         127            17            "The Doll"  Andy Ackerman
#  16         128            18     "The Friars Club"  Andy Ackerman
#  17         129            19      "The Wig Master"  Andy Ackerman
#  18         130            20         "The Calzone"  Andy Ackerman
#  19      131132          2122  "The Bottle Deposit"  Andy Ackerman
#  20         133            23        "The Wait Out"  Andy Ackerman
#  21         134            24     "The Invitations"  Andy Ackerman
#
#                                             Written by Original air date [17]  \
#  0                                         Larry David     September 21, 1995
#  1                                         Larry David     September 28, 1995
#  2                                         Larry David        October 5, 1995
#  3                             Tom Gammill & Max Pross       October 12, 1995
#  4                            Gregg Kavet & Andy Robin       October 19, 1995
#  5                                      Spike Feresten       November 2, 1995
#  6                           Alec Berg & Jeff Schaffer       November 9, 1995
#  7                                        David Mandel      November 16, 1995
#  8                                       Peter Mehlman       December 7, 1995
#  9                             Tom Gammill & Max Pross      December 14, 1995
#  10                                       Carol Leifer        January 4, 1996
#  11                           Gregg Kavet & Andy Robin       January 25, 1996
#  12                          Alec Berg & Jeff Schaffer       February 1, 1996
#  13                       Larry David & Jerry Seinfeld       February 8, 1996
#  14                     Peter Mehlman & Marjorie Gross      February 15, 1996
#  15                            Tom Gammill & Max Pross      February 22, 1996
#  16                                       David Mandel          March 7, 1996
#  17                                     Spike Feresten          April 4, 1996
#  18                          Alec Berg & Jeff Schaffer         April 25, 1996
#  19                           Gregg Kavet & Andy Robin            May 2, 1996
#  20  Story by : Peter Mehlman & Matt SelmanTeleplay...            May 9, 1996
#  21                                        Larry David           May 16, 1996
#
#      Prod.code [127] US viewers(millions)
#  0               701            37.6[128]
#  1               702            34.5[129]
#  2               703            34.6[130]
#  3               704            32.3[131]
#  4               705            32.6[132]
#  5               706            33.1[133]
#  6               707            33.9[134]
#  7               708            33.4[135]
#  8               709            32.3[136]
#  9               710            31.4[137]
#  10              711            35.1[138]
#  11              712            32.0[139]
#  12              713            37.1[140]
#  13           714717            35.9[141]
#  14              715            32.3[142]
#  15              716            32.9[143]
#  16              718            32.7[144]
#  17              719            30.5[145]
#  18              720            28.5[146]
#  19           721722            32.4[147]
#  20              723            29.9[148]
#  21              724            33.2[149]  ,
#      No.overall  No. inseason                   Title         Directed by  \
#  0          135             1        "The Foundation"       Andy Ackerman
#  1          136             2         "The Soul Mate"       Andy Ackerman
#  2          137             3     "The Bizarro Jerry"       Andy Ackerman
#  3          138             4      "The Little Kicks"       Andy Ackerman
#  4          139             5           "The Package"       Andy Ackerman
#  5          140             6          "The Fatigues"       Andy Ackerman
#  6          141             7            "The Checks"       Andy Ackerman
#  7          142             8   "The Chicken Roaster"       Andy Ackerman
#  8          143             9        "The Abstinence"       Andy Ackerman
#  9          144            10      "The Andrea Doria"       Andy Ackerman
#  10         145            11      "The Little Jerry"       Andy Ackerman
#  11         146            12             "The Money"       Andy Ackerman
#  12         147            13          "The Comeback"  David Owen Trainor
#  13         148            14    "The Van Buren Boys"       Andy Ackerman
#  14         149            15             "The Susie"       Andy Ackerman
#  15         150            16           "The Pothole"       Andy Ackerman
#  16         151            17   "The English Patient"       Andy Ackerman
#  17         152            18               "The Nap"       Andy Ackerman
#  18         153            19         "The Yada Yada"       Andy Ackerman
#  19         154            20        "The Millennium"       Andy Ackerman
#  20         155            21       "The Muffin Tops"       Andy Ackerman
#  21         156            22  "The Summer of George"       Andy Ackerman
#
#                                       Written by Original air date [17]  \
#  0                     Alec Berg & Jeff Schaffer     September 19, 1996
#  1                                 Peter Mehlman     September 26, 1996
#  2                                  David Mandel        October 3, 1996
#  3                                Spike Feresten       October 10, 1996
#  4                           Jennifer Crittenden       October 17, 1996
#  5                      Gregg Kavet & Andy Robin       October 31, 1996
#  6   Steve O'Donnell and Tom Gammill & Max Pross       November 7, 1996
#  7                     Alec Berg & Jeff Schaffer      November 14, 1996
#  8                                   Steve Koren      November 21, 1996
#  9                                Spike Feresten      December 19, 1996
#  10                          Jennifer Crittenden        January 9, 1997
#  11                                Peter Mehlman       January 16, 1997
#  12                     Gregg Kavet & Andy Robin       January 30, 1997
#  13                                  Darin Henry       February 6, 1997
#  14                                 David Mandel      February 13, 1997
#  15              Steve O'Donnell and Dan O'Keefe      February 20, 1997
#  16                                  Steve Koren         March 13, 1997
#  17                     Gregg Kavet & Andy Robin         April 10, 1997
#  18              Peter Mehlman and Jill Franklyn         April 24, 1997
#  19                          Jennifer Crittenden            May 1, 1997
#  20                               Spike Feresten            May 8, 1997
#  21                    Alec Berg & Jeff Schaffer           May 15, 1997
#
#      Prod.code [150] US viewers(millions)
#  0               801           33.72[151]
#  1               802           33.24[152]
#  2               803           31.62[153]
#  3               804           32.24[154]
#  4               805           30.13[155]
#  5               806           30.33[156]
#  6               807           32.01[157]
#  7               808           34.09[158]
#  8               809           34.35[159]
#  9               810           29.65[160]
#  10              811           34.48[161]
#  11              813           37.34[162]
#  12              812           33.50[163]
#  13              814           33.82[164]
#  14              815           32.00[165]
#  15              816           33.83[166]
#  16              817           31.27[167]
#  17              818           32.22[168]
#  18              819           31.64[169]
#  19              820           29.30[170]
#  20              821           31.09[171]
#  21              822           29.80[172]  ,
#      No.overall  No. inseason                           Title    Directed by  \
#  0          157             1              "The Butter Shave"  Andy Ackerman
#  1          158             2                     "The Voice"  Andy Ackerman
#  2          159             3              "The Serenity Now"  Andy Ackerman
#  3          160             4                     "The Blood"  Andy Ackerman
#  4          161             5                 "The Junk Mail"  Andy Ackerman
#  5          162             6         "The Merv Griffin Show"  Andy Ackerman
#  6          163             7                    "The Slicer"  Andy Ackerman
#  7          164             8                  "The Betrayal"  Andy Ackerman
#  8          165             9                   "The Apology"  Andy Ackerman
#  9          166            10                    "The Strike"  Andy Ackerman
#  10         167            11                "The Dealership"  Andy Ackerman
#  11         168            12          "The Reverse Peephole"  Andy Ackerman
#  12         169            13                   "The Cartoon"  Andy Ackerman
#  13         170            14                 "The Strongbox"  Andy Ackerman
#  14         171            15                    "The Wizard"  Andy Ackerman
#  15         172            16                   "The Burning"  Andy Ackerman
#  16         173            17                 "The Bookstore"  Andy Ackerman
#  17         174            18                   "The Frogger"  Andy Ackerman
#  18         175            19                      "The Maid"  Andy Ackerman
#  19         176            20          "The Puerto Rican Day"  Andy Ackerman
#  20      177178          2122  "The Chronicle""The Clip Show"  Andy Ackerman
#  21      179180          2324                    "The Finale"  Andy Ackerman
#
#                                             Written by Original air date [17]  \
#  0            Alec Berg & Jeff Schaffer & David Mandel     September 25, 1997
#  1            Alec Berg & Jeff Schaffer & David Mandel        October 2, 1997
#  2                                         Steve Koren        October 9, 1997
#  3                                         Dan O'Keefe       October 16, 1997
#  4                                      Spike Feresten       October 30, 1997
#  5                                   Bruce Eric Kaplan       November 6, 1997
#  6   Story by : Gregg Kavet & Andy Robin & Darin He...      November 13, 1997
#  7                        David Mandel & Peter Mehlman      November 20, 1997
#  8                                 Jennifer Crittenden      December 11, 1997
#  9           Dan O'Keefe and Alec Berg & Jeff Schaffer      December 18, 1997
#  10                                        Steve Koren        January 8, 1998
#  11                                     Spike Feresten       January 15, 1998
#  12                                  Bruce Eric Kaplan       January 29, 1998
#  13  Story by : Dan O'Keefe & Billy KimballTeleplay...       February 5, 1998
#  14                                      Steve Lookner      February 26, 1998
#  15                                Jennifer Crittenden         March 19, 1998
#  16  Story by : Spike Feresten and Darin Henry & Ma...          April 9, 1998
#  17  Story by : Gregg Kavet & Andy Robin and Steve ...         April 23, 1998
#  18  Story by : Alec Berg & David Mandel & Jeff Sch...         April 30, 1998
#  19  Alec Berg, Jennifer Crittenden, Spike Feresten...            May 7, 1998
#  20                                        Darin Henry           May 14, 1998
#  21                                        Larry David           May 14, 1998
#
#      Prod.code [173] US viewers(millions)
#  0               901           37.78[174]
#  1               902           30.93[175]
#  2               903           30.15[176]
#  3               904           31.45[177]
#  4               905           30.24[178]
#  5               906           31.64[179]
#  6               907           32.77[180]
#  7               908           33.99[181]
#  8               909           30.47[182]
#  9               910           30.79[183]
#  10              911           32.86[184]
#  11              912           33.48[185]
#  12              913           33.19[186]
#  13              914           31.63[187]
#  14              915           30.51[188]
#  15              916           30.92[189]
#  16              917           29.60[190]
#  17              918           30.66[191]
#  18              919           33.32[192]
#  19              920           38.78[193]
#  20           921922           58.53[194]
#  21           923924           76.26[194]  ,
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteSeinfeld  \
#  0                                           Episodes
#  1                                         Characters
#  2                                            Related
#  3                                   Portal  Category
#
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteSeinfeld.1
#  0  Season 1 Season 2 Season 3 Season 4 Season 5 S...
#  1  Jerry Seinfeld George Costanza Elaine Benes Co...
#  2  Awards and nominations Monk's Café Festivus Ke...
#  3                                   Portal  Category                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ,
#           vteSeinfeld episodes  \
#  0                    Season 1
#  1                    Season 2
#  2                    Season 3
#  3                    Season 4
#  4                    Season 5
#  5                    Season 6
#  6                    Season 7
#  7                    Season 8
#  8                    Season 9
#  9  Indicates two-part episode
#
#                                vteSeinfeld episodes.1
#  0  "The Seinfeld Chronicles" "The Stake Out" "The...
#  1  "The Ex-Girlfriend" "The Pony Remark" "The Jac...
#  2  "The Note" "The Truth" "The Pen" "The Dog" "Th...
#  3  "The Trip" "The Pitch" "The Ticket" "The Walle...
#  4  "The Mango" "The Puffy Shirt" "The Glasses" "T...
#  5  "The Chaperone" "The Big Salad" "The Pledge Dr...
#  6  "The Engagement" "The Postponement" "The Maest...
#  7  "The Foundation" "The Soul Mate" "The Bizarro ...
#  8  "The Butter Shave" "The Voice" "The Serenity N...
#  9                         Indicates two-part episode  ,
#         vteJerry Seinfeld                                vteJerry Seinfeld.1
#  0  Television/web series  Seinfeld (episodes, awards) (1989–98) The Marr...
#  1                   Film                   Comedian (2002) Bee Movie (2007)
#  2               Stand-up  Stand-Up Confidential (1987) I'm Telling You f...
#  3                  Books  SeinLanguage (1993) Halloween (2002) Is This A...
#  4                Related  Jessica Seinfeld (wife) Carol Leifer (former r...,
#    vteLarry David                                   vteLarry David.1
#  0    Filmography                                        Filmography
#  1     Television  Fridays (writer, star; 1980–82) Saturday Night...
#  2           Film  Sour Grapes (writer, director; 1998) Envy (pro...
#  3        Theater              Fish in the Dark (writer, star; 2015)
#  4        Related  Laurie David (ex-wife) George Steinbrenner Geo...]

# %%
tables[1]
# Out:
#    No.overall  No. inseason                      Title   Directed by  \
# 0           1             1  "The Seinfeld Chronicles"     Art Wolff
# 1           2             2            "The Stake Out"  Tom Cherones
# 2           3             3              "The Robbery"  Tom Cherones
# 3           4             4           "Male Unbonding"  Tom Cherones
# 4           5             5            "The Stock Tip"  Tom Cherones
#
#                      Written by Original air date [17]  Prod.code [18]  \
# 0  Larry David & Jerry Seinfeld           July 5, 1989             101
# 1  Larry David & Jerry Seinfeld           May 31, 1990             103
# 2                  Matt Goldman           June 7, 1990             104
# 3  Larry David & Jerry Seinfeld          June 14, 1990             102
# 4  Larry David & Jerry Seinfeld          June 21, 1990             105
#
#   US viewers(millions)
# 0             15.4[19]
# 1             22.5[20]
# 2             19.7[21]
# 3             19.1[22]
# 4             19.4[23]

# %%
tables[2]
# Out:
#     No.overall  No. inseason                     Title   Directed by  \
# 0            6             1       "The Ex-Girlfriend"  Tom Cherones
# 1            7             2         "The Pony Remark"  Tom Cherones
# 2            8             3              "The Jacket"  Tom Cherones
# 3            9             4       "The Phone Message"  Tom Cherones
# 4           10             5           "The Apartment"  Tom Cherones
# 5           11             6              "The Statue"  Tom Cherones
# 6           12             7             "The Revenge"  Tom Cherones
# 7           13             8        "The Heart Attack"  Tom Cherones
# 8           14             9                "The Deal"  Tom Cherones
# 9           15            10         "The Baby Shower"  Tom Cherones
# 10          16            11  "The Chinese Restaurant"  Tom Cherones
# 11          17            12              "The Busboy"  Tom Cherones
#
#                       Written by Original air date [17]  Prod.code [18]  \
# 0   Larry David & Jerry Seinfeld       January 23, 1991             201
# 1   Larry David & Jerry Seinfeld       January 30, 1991             202
# 2   Larry David & Jerry Seinfeld       February 6, 1991             205
# 3   Larry David & Jerry Seinfeld      February 13, 1991             207
# 4                  Peter Mehlman          April 4, 1991             208
# 5                  Larry Charles         April 11, 1991             210
# 6                    Larry David         April 18, 1991             212
# 7                  Larry Charles         April 25, 1991             211
# 8                    Larry David            May 2, 1991             213
# 9                  Larry Charles           May 16, 1991             204
# 10  Larry David & Jerry Seinfeld           May 23, 1991             206
# 11  Larry David & Jerry Seinfeld          June 26, 1991             203
#
#    US viewers(millions)
# 0              15.6[24]
# 1              15.2[25]
# 2              14.8[26]
# 3              13.6[27]
# 4              24.7[28]
# 5              23.3[29]
# 6              19.6[30]
# 7              20.6[31]
# 8              22.9[32]
# 9              17.2[33]
# 10             16.8[34]
# 11             12.5[35]
